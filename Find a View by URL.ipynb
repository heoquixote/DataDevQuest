# %%
pip install tableauserverclient
# Out:
# Requirement already satisfied: tableauserverclient in /Users/heojinseong/.conda/lib/python3.12/site-packages (0.34)
# Requirement already satisfied: defusedxml>=0.7.1 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from tableauserverclient) (0.7.1)
# Requirement already satisfied: packaging>=23.1 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from tableauserverclient) (24.1)
# Requirement already satisfied: requests>=2.32 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from tableauserverclient) (2.32.3)
# Requirement already satisfied: urllib3<3,>=2.2.2 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from tableauserverclient) (2.2.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from tableauserverclient) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from requests>=2.32->tableauserverclient) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from requests>=2.32->tableauserverclient) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/heojinseong/.conda/lib/python3.12/site-packages (from requests>=2.32->tableauserverclient) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tableauserverclient as TSC
import urllib.parse
import os
from dotenv import load_dotenv

def main():
    # Load environment variables
    load_dotenv()

    # Tableau Server credentials
    tableau_server = os.getenv("TABLEAU_SERVER")
    tableau_username = os.getenv("TABLEAU_USERNAME")
    tableau_password = os.getenv("TABLEAU_PASSWORD")
    tableau_site = os.getenv("TABLEAU_SITE")  # Use None for the default site

    if not all([tableau_server, tableau_username, tableau_password]):
        print("Error: Missing Tableau credentials. Check your .env file.")
        return

    # Prompt user for view URL
    user_input = input("Enter the URL of the Tableau view to search for: ").strip()

    # Parse and extract view information from the URL
    parsed_url = urllib.parse.urlparse(user_input)
    view_path = parsed_url.path.split("/")[-1] if "/" in parsed_url.path else user_input

    # Authenticate with Tableau Server
    tableau_auth = TSC.TableauAuth(tableau_username, tableau_password)
    server = TSC.Server(tableau_server)
    server.use_server_version()

    try:
        with server.auth.sign_in(tableau_auth):
            # Search for the view
            req_options = TSC.RequestOptions()
            req_options.filter.add(
                TSC.Filter(
                    TSC.RequestOptions.Field.Name,
                    TSC.RequestOptions.Operator.Equals,
                    view_path,
                )
            )

            views, pagination_item = server.views.get(req_options)

            if views:
                print("\nFound the following view(s):\n")
                for idx, view in enumerate(views, start=1):
                    # Get workbook details
                    workbook = server.workbooks.get_by_id(view.workbook_id)
                    
                    # Get project details
                    all_projects, _ = server.projects.get()
                    project = next((proj for proj in all_projects if proj.id == workbook.project_id), None)

                    print(f"{idx})")
                    print(f"- View Name: {view.name}")
                    print(f"- View ID: {view.id}")
                    print(f"- Workbook Name: {workbook.name}")
                    print(f"- Project Name: {project.name if project else 'Unknown'}")
                    print(f"- View URL: {tableau_server}/views/{workbook.name}/{view.name}\n")
            else:
                print("\nNo views found matching the given URL.\n")

    except TSC.ServerResponseError as e:
        print(f"An error occurred while communicating with Tableau Server: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")


if __name__ == "__main__":
    main()
# Out:
# Found the following view(s):
#
# 1)
# - View Name: Dashboard
# - View ID: a300e744-f45c-460c-bcde-d22fb0b7e98a
# - Workbook Name: 지역별 매장 리포트
# - Project Name: Sample Dashboard (v2.0)
# - View URL: https://tableau-report.com/views/지역별 매장 리포트/Dashboard
#
# 2)
# - View Name: Dashboard
# - View ID: 558bbc28-8661-47b5-ad43-b91736f2a6a1
# - Workbook Name: Monthly dashboard (Reebok)
# - Project Name: One page dashboard
# - View URL: https://tableau-report.com/views/Monthly dashboard (Reebok)/Dashboard
#
# 3)
# - View Name: Dashboard
# - View ID: af40cb96-381b-42b3-aeb9-93dfbb273859
# - Workbook Name: CRM Dashboard (Outback)
# - Project Name: One page dashboard
# - View URL: https://tableau-report.com/views/CRM Dashboard (Outback)/Dashboard
#
# 4)
# - View Name: Dashboard
# - View ID: 43127d2a-cd22-4542-8a74-5b2507691dec
# - Workbook Name: Project Dashboard(IchoiceMembership)
# - Project Name: One page dashboard
# - View URL: https://tableau-report.com/views/Project Dashboard(IchoiceMembership)/Dashboard
#
# 5)
# - View Name: Dashboard
# - View ID: 1bd209ee-70b9-4e9a-b504-5e198e365dd7
# - Workbook Name: Report
# - Project Name: Brand N
# - View URL: https://tableau-report.com/views/Report/Dashboard
#
# 6)
# - View Name: Dashboard
# - View ID: da642621-194e-4898-9fa8-bb36760e8349
# - Workbook Name: Online Ad Report
# - Project Name: Sample Dashboard (v2.0)
# - View URL: https://tableau-report.com/views/Online Ad Report/Dashboard
#
# 7)
# - View Name: Dashboard
# - View ID: 14e86b69-8459-4888-ac64-b894e9e46836
# - Workbook Name: IKEA_School start_Comm result
# - Project Name: Campaign Analysis
# - View URL: https://tableau-report.com/views/IKEA_School start_Comm result/Dashboard
#
# 8)
# - View Name: Dashboard
# - View ID: b6443fbd-e5df-4af8-ac9c-f9bc1d4a9b43
# - Workbook Name: ttt
# - Project Name: Brand N
# - View URL: https://tableau-report.com/views/ttt/Dashboard
#
# 9)
# - View Name: Dashboard
# - View ID: a487fd2c-4e4c-4f67-a95d-9aa1d03b2a81
# - Workbook Name: 통합분석시스템구축_대시보드
# - Project Name: Sample Dashboard (v2.0)
# - View URL: https://tableau-report.com/views/통합분석시스템구축_대시보드/Dashboard
#
# 10)
# - View Name: dashboard
# - View ID: 195ec474-d407-486e-a06f-92eefbcf12a3
# - Workbook Name: [인턴대시보드] 1주차 HR - Karina
# - Project Name: 인턴대시보드
# - View URL: https://tableau-report.com/views/[인턴대시보드] 1주차 HR - Karina/dashboard
#
# 11)
# - View Name: Dashboard
# - View ID: 4e962f71-316c-453f-a731-ce034c4bebf5
# - Workbook Name: [인턴대시보드] 2주차 호텔 - Karina
# - Project Name: 인턴대시보드
# - View URL: https://tableau-report.com/views/[인턴대시보드] 2주차 호텔 - Karina/Dashboard
#
# 12)
# - View Name: Dashboard
# - View ID: e6bd8fa7-b6ec-410b-abcc-335e710c0f0d
# - Workbook Name: 수익성분석
# - Project Name: Aproject
# - View URL: https://tableau-report.com/views/수익성분석/Dashboard
#
# 13)
# - View Name: Dashboard
# - View ID: 1255457c-c751-4809-8959-9a14c351a420
# - Workbook Name: 통합분석 대시보드_필터 수정
# - Project Name: Sample Dashboard (v2.0)
# - View URL: https://tableau-report.com/views/통합분석 대시보드_필터 수정/Dashboard
#
# 14)
# - View Name: Dashboard
# - View ID: 9a2fd5e3-2222-497f-b2cb-a557539dc84c
# - Workbook Name: BMW_Teleservice Dashboard_v3
# - Project Name: Aproject
# - View URL: https://tableau-report.com/views/BMW_Teleservice Dashboard_v3/Dashboard
